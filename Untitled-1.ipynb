# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from state_choices import STATE_CHOICES

#load the dataset 
data_path = './Metro_invt_fs_uc_sfrcondo_sm_month.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0    102001         0    United States    country       NaN   1421529.0
# 1    394913         1     New York, NY        msa        NY     73707.0
# 2    753899         2  Los Angeles, CA        msa        CA     21998.0
# 3    394463         3      Chicago, IL        msa        IL     38581.0
# 4    394514         4       Dallas, TX        msa        TX     24043.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-09-30  \
# 0   1500193.0   1592414.0   1660614.0   1709143.0  ...    959735.0
# 1     80345.0     85864.0     90067.0     91881.0  ...     42515.0
# 2     23784.0     25605.0     27109.0     28811.0  ...     16032.0
# 3     42253.0     45757.0     47492.0     48984.0  ...     23569.0
# 4     25876.0     28225.0     30490.0     32408.0  ...     23342.0
#
#    2023-10-31  2023-11-30  2023-12-31  2024-01-31  2024-02-29  2024-03-31  \
# ...

# %%
# Transpose the dataframe to have dates as rows for easier plotting
# We will also filter for a few regions to make the plots more readable
regions_to_plot = ['United States', 'New York, NY', 'Los Angeles, CA', 'Chicago, IL', 'Dallas, TX']
df_filtered = df[df['StateName'].isin(STATE_CHOICES)]
df_transposed = df_filtered.set_index('StateName').T

# Reset the index to have dates as a column
df_transposed.reset_index(inplace=True)
df_transposed.rename(columns={'index': 'Date'}, inplace=True)

# Convert the Date column to datetime format
df_transposed['Date'] = pd.to_datetime(df_transposed['Date'], errors='coerce')

# Drop rows with NaT in the Date column
df_transposed.dropna(subset=['Date'], inplace=True)

df_transposed
# Out:
# C:\Users\CRC\AppData\Local\Temp\ipykernel_10300\3998147280.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_transposed['Date'] = pd.to_datetime(df_transposed['Date2'], errors='coerce')
# StateName       Date2       NY       CA       IL       TX       TX       VA  \
# 4          2018-03-31  73707.0  21998.0  38581.0  24043.0  25618.0  20262.0
# 5          2018-04-30  80345.0  23784.0  42253.0  25876.0  27360.0  23466.0
# 6          2018-05-31  85864.0  25605.0  45757.0  28225.0  29634.0  26180.0
# 7          2018-06-30  90067.0  27109.0  47492.0  30490.0  31129.0  26325.0
# 8          2018-07-31  91881.0  28811.0  48984.0  32408.0  32397.0  25145.0
# ..                ...      ...      ...      ...      ...      ...      ...
# 75         2024-02-29  34858.0  13754.0  18342.0  21401.0  21817.0   8048.0
# ...
